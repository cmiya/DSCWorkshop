# %% [markdown]
# # Intro to Text Analysis
#
# ## <font color='orange'>Workshop Description</font>
#
# This hands-on workshop will introduce students to the basics of text analysis using Python’s Natural Language Toolkit (NLTK) library. Students will learn how to search for patterns in a text and extract and summarize information about its features. This class is designed for beginners and will especially appeal to those in humanities fields.
#
# By the end of the workshop, students will know how to:
#
# - Setup and install required software
# - Load a text file
# - Clean up and tokenize a text
# - Search for words in context
# - Chart word frequency
# - Tag parts-of-speech
#
# ### Requirements:
# - Bring a laptop
# - Download the latest version of anaconda: (https://docs.anaconda.com/anaconda/install/)
# - If you already have an older version of anaconda installed, make sure to update it:  (https://docs.anaconda.com/anaconda/install/update-version/)
#
# ### Resources:
# - Getting Started with NLTK [(online)](https://www.nltk.org/book/ch01.html)
# - Data Camp's Beginner's Guide to NLTK [(online)](https://www.datacamp.com/community/tutorials/text-analytics-beginners-nltk)
# - Markdown Cheat Sheet [(online)](https://www.markdownguide.org/cheat-sheet/)
# - Programming Historian [(online)](https://programminghistorian.org/)

# %% [markdown]
# ## <font color='orange'>What is Text Analysis?</font>
# - Searching for patterns
# - Comparative
# - What makes a feature significant?
#
# ### What can we use it for?

# %% [markdown]
# ## <font color='orange'>What is Jupyter Notebook?</font>
#
# - Jupyter Notebook is a Graphic User Interface (GUI aka "gooey") that sits on top of the computer code and makes it easier to interact with.
# - Jupyter Notebook is for:
#     - a) writing and executing "live" computer code
#     - b) creating written and visual notes or commentary (like for tutorials!)
#
# ### Using Jupyter:
# - **Cells** are boxes for entering code or text.
# - Switch between **Cell Types** using the dropdown menu:
#     - a) **Code**: e.g. Python, Java, R
#     - b) **Markdown**: create text and visual content, easy-to-read and write
#
# ### Working with Cells
# - **Double-click** a Cell to edit it.
# - You can **Insert** Cells above or below, **Copy and Paste** Cells contents, **Move** Cells up/down, and **Delete** Cells.
# - Click **Shift + Return** to execute Cell contents (run code).
# - Click the **STOP** icon to stop (interrupt) code.

# %% [markdown]
# ## <font color='orange'>Getting Started with NLTK</font>
#
# ### Open Jupyter Notebook
# - Open Anaconda-Navigator (in Applications)
# - Under Home, click the 'Jupyter Notebook' icon to launch.

# %% [markdown]
# ### Import the NLTK Library

# %%
#Import the NLTK library 

import nltk
nltk.download('popular')
nltk.downloader.download('vader_lexicon')
nltk.downloader.download('universal_tagset')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# ...

# %% [markdown]
# ### Load Text from Text File

# %%
#Load text from a text file

f1 = open('/Users/chelseamiya/Desktop/DSCWorkshop-master/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/DSCWorkshop-master/Yovanovitch.txt')

#Read file (to view what's inside)
raw = f1.read()

print(raw)
# Out:
# I appreciate the opportunity to speak again to the members of this committee. First, let me offer my thanks to the men and women of the US Department of State, who have committed their professional lives to support the foreign policy work of the United States. In particular, I want to thank my staff at the US Mission to the European Union. Your integrity, dedication, and hard work often performed without public acclaim or recognition serve as a shining example of true public service. And I am personally grateful to work beside you each and every day.It is my honor to serve as the US Ambassador to the European Union. The US Mission to the EU is the direct link between the United States and the European Union and its members. America’s longest standing allies and one of the largest economic blocks in the world. Every day I work to support a strong, united and peaceful Europe. Strengthening our ties with Europe serves both American and European goals as we together promote political sta
# ...

# %% [markdown]
# ### Load from a URL

# %%
#Load a text file from a URL

from urllib import request

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Sondland.txt"
response = request.urlopen(url)
f1 = response.read().decode('utf8')

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Yovanovitch.txt"
response = request.urlopen(url)
f2 = response.read().decode('utf8')

print(f2)
# Out:
# Thank you for the opportunity to start with this statement. To reintroduce myself to the committee and to highlight parts of my biography and experience, I come before you as an American citizen who has devoted the majority of my life, 33 years, to service to the country that all of us love. Like my colleagues, I entered the foreign service understanding that my job was to implement the foreign policy interests of this nation as defined by the president and Congress and to do so regardless of which person or party was in power. I had no agenda other than to pursue our stated foreign policy goals. My service is an expression of gratitude for all that this country has given to me and to my family. My late parents did not have the good fortune to come of age in a free society.
# ...

# %% [markdown]
# ### Calculate number of words

# %%
#Compare the length of each testimony

len(f2)
# Out:
# 17339

# %% [markdown]
# ### Tokenize Words
# - Split the text into a "Bag of Words" (BOW)
# - Each word is "counted" seperately

# %%
#Tokenize words

text = f2

from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
len(tokenized_word)
# Out:
# ['Thank', 'you', 'for', 'the', 'opportunity', 'to', 'start', 'with', 'this', 'statement', '.', 'To', 'reintroduce', 'myself', 'to', 'the', 'committee', 'and', 'to', 'highlight', 'parts', 'of', 'my', 'biography', 'and', 'experience', ',', 'I', 'come', 'before', 'you', 'as', 'an', 'American', 'citizen', 'who', 'has', 'devoted', 'the', 'majority', 'of', 'my', 'life', ',', '33', 'years', ',', 'to', 'service', 'to', 'the', 'country', 'that', 'all', 'of', 'us', 'love', '.', 'Like', 'my', 'colleagues', ',', 'I', 'entered', 'the', 'foreign', 'service', 'understanding', 'that', 'my', 'job', 'was', 'to', 'implement', 'the', 'foreign', 'policy', 'interests', 'of', 'this', 'nation', 'as', 'defined', 'by', 'the', 'president', 'and', 'Congress', 'and', 'to', 'do', 'so', 'regardless', 'of', 'which', 'person', 'or', 'party', 'was', 'in', 'power', '.', 'I', 'had', 'no', 'agenda', 'other', 'than', 'to', 'pursue', 'our', 'stated', 'foreign', 'policy', 'goals', '.', 'My', 'service', 'is', 'an', 'express
# ...

# %% [markdown]
# ### Clean up text

# %%
#Remove numbers and punctuation

#Create a empty "list" (like a bin) to put the words in
clean_text = []

#For each word that contains only numbers or letters, add it to the list
for word in tokenized_word:
    if word.isalpha():
        clean_text.append(word)

#Print the contents of our (now full) list
print(clean_text)

#Print the length of items in the list
len(clean_text)
# Out:
# ['Thank', 'you', 'for', 'the', 'opportunity', 'to', 'start', 'with', 'this', 'statement', 'To', 'reintroduce', 'myself', 'to', 'the', 'committee', 'and', 'to', 'highlight', 'parts', 'of', 'my', 'biography', 'and', 'experience', 'I', 'come', 'before', 'you', 'as', 'an', 'American', 'citizen', 'who', 'has', 'devoted', 'the', 'majority', 'of', 'my', 'life', 'years', 'to', 'service', 'to', 'the', 'country', 'that', 'all', 'of', 'us', 'love', 'Like', 'my', 'colleagues', 'I', 'entered', 'the', 'foreign', 'service', 'understanding', 'that', 'my', 'job', 'was', 'to', 'implement', 'the', 'foreign', 'policy', 'interests', 'of', 'this', 'nation', 'as', 'defined', 'by', 'the', 'president', 'and', 'Congress', 'and', 'to', 'do', 'so', 'regardless', 'of', 'which', 'person', 'or', 'party', 'was', 'in', 'power', 'I', 'had', 'no', 'agenda', 'other', 'than', 'to', 'pursue', 'our', 'stated', 'foreign', 'policy', 'goals', 'My', 'service', 'is', 'an', 'expression', 'of', 'gratitude', 'for', 'all', 'that',
# ...

# %% [markdown]
# ### Calculate lexical diversity

# %%
#Calculate lexical diversity by...
#Dividing the total number of words by the number of unique words

len(set(word.lower() for word in clean_text)) / len(clean_text)
# Out:
# 0.32466181061394384

# %%
#What if you want to repeat a calculation on several texts?

#Create a FUNCTION to build a tool from a block of code

def lexical_diversity(text):

    textWords = []
    
    from nltk.tokenize import word_tokenize
    tokenized_word=word_tokenize(text)
    
    for word in tokenized_word:
        if word.isalpha():
            textWords.append(word)

    return len(set(word.lower() for word in textWords)) / len(textWords)

# %%
url = "https://github.com/cmiya/DSCWorkshop/raw/master/Sondland.txt"
response = request.urlopen(url)
f1 = response.read().decode('utf8')

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Yovanovitch.txt"
response = request.urlopen(url)
f2 = response.read().decode('utf8')

lexical_diversity(f1)
# Out:
# 0.22382742924995053

# %% [markdown]
# ### Word Frequency

# %%
from nltk.probability import FreqDist
fdist = FreqDist(clean_text)
print(fdist)
# Out:
# <FreqDist with 989 samples and 2883 outcomes>

# %%
fdist.most_common(20)
# Out:
# [('the', 168),
#  ('to', 104),
#  ('and', 96),
#  ('of', 72),
#  ('in', 50),
#  ('I', 48),
#  ('a', 47),
#  ('our', 39),
#  ('that', 37),
#  ('Ukraine', 30),
#  ('is', 28),
#  ('as', 26),
#  ('s', 26),
#  ('for', 24),
#  ('with', 22),
#  ('are', 20),
#  ('not', 20),
#  ('me', 19),
#  ('have', 18),
#  ('US', 18)]

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# ### Eliminate Stopwords
# - The most frequent words are often function words (expressing grammatical relationships)
# - Function words do not tell you about the content or meaning of a text
# - Eliminate these with a Stopword List

# %%
#NLTK has a built in list of stopwords
#Load the list
from nltk.corpus import stopwords

#Choose the stopword language
stop_words=set(stopwords.words("english"))

#Print (show) the contents of the list
print(stop_words)
# Out:
# {'you', "wouldn't", 'until', 'all', 'themselves', 'yourselves', 'yours', 'am', 'shan', 'wouldn', 'same', 'on', 'whom', 'with', 'needn', 'some', 'should', 'each', 'a', 'once', "shan't", 'under', 'hers', 'nor', "won't", 'haven', 'what', 'that', 'when', 'because', 'doesn', 'not', 'there', 'of', 'during', 'my', "she's", 've', 'ourselves', 'has', 'such', "hadn't", 'our', 'was', 'herself', 'don', 'will', 'this', 'to', "shouldn't", 'are', 's', 'hasn', 'down', 'these', 'himself', 'having', 'were', "you'll", 'the', 'o', "don't", "mustn't", 'no', 'can', 'him', 'll', 'now', 'did', 'as', "aren't", 'he', 'theirs', 'itself', 'while', 'through', "should've", 'them', 'own', 'about', 'too', 'i', 'if', 'more', 'out', 'be', "didn't", 'aren', 'm', 'where', 'then', 'below', 'had', 'from', 'have', "you're", 'an', "couldn't", 'do', 'by', 'any', 'who', 'off', 'which', 'or', "that'll", "weren't", "needn't", 'only', 'again', 'wasn', 'didn', "mightn't", 'd', 'hadn', 'their', 'myself', "you've", "wasn't", 'does
# ...

# %%
#Remove Stopwords from our BOW

filtered_word=[]
for w in clean_text:
    if w not in stop_words:
        filtered_word.append(w)
print("Tokenized Sentence:",tokenized_word)
print(len(tokenized_word))

print("Filtered Sentence:",filtered_word)
print(len(filtered_word))
# Out:
# Tokenized Sentence: ['Thank', 'you', 'for', 'the', 'opportunity', 'to', 'start', 'with', 'this', 'statement', '.', 'To', 'reintroduce', 'myself', 'to', 'the', 'committee', 'and', 'to', 'highlight', 'parts', 'of', 'my', 'biography', 'and', 'experience', ',', 'I', 'come', 'before', 'you', 'as', 'an', 'American', 'citizen', 'who', 'has', 'devoted', 'the', 'majority', 'of', 'my', 'life', ',', '33', 'years', ',', 'to', 'service', 'to', 'the', 'country', 'that', 'all', 'of', 'us', 'love', '.', 'Like', 'my', 'colleagues', ',', 'I', 'entered', 'the', 'foreign', 'service', 'understanding', 'that', 'my', 'job', 'was', 'to', 'implement', 'the', 'foreign', 'policy', 'interests', 'of', 'this', 'nation', 'as', 'defined', 'by', 'the', 'president', 'and', 'Congress', 'and', 'to', 'do', 'so', 'regardless', 'of', 'which', 'person', 'or', 'party', 'was', 'in', 'power', '.', 'I', 'had', 'no', 'agenda', 'other', 'than', 'to', 'pursue', 'our', 'stated', 'foreign', 'policy', 'goals', '.', 'My', 'service', 
# ...

# %% [markdown]
# ### Plot Frequency Distibution

# %%
from nltk.probability import FreqDist
fdist = FreqDist(filtered_word)
print(fdist)

# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
# Out:
# <FreqDist with 881 samples and 1590 outcomes>

# %% [markdown]
# ### Find words in context

# %%
##Find word concordance for raw text

text = nltk.Text(clean_text)
text.concordance('security')
# Out:
# Displaying 8 of 8 matches:
# s well as a force multiplier on the security side We see the potential in Ukrain
# hip The US has provided significant security assistance since the onset of the w
# est and profit Corruption is also a security issue because corrupt officials are
# n short it is in America s national security interest to help Ukraine transform
# iscussions surrounding the delay of security assistance to Ukraine in the summer
# ess to safeguard the vital national security interests of the United States This
# hat s an investment in our national security It s an investment in our future an
#  facilitate trade and commerce work security issues represent the US and report

# %%
#Find words that appear in similar contexts

text.similar("Trump")
# Out:
# reagan smear clinton previous obama

# %% [markdown]
# ### Plot Lexical Dispertion
# - Compare how different words are distributed over the text

# %%
text.dispersion_plot(["US", "Trump", "public", "my", "aid", "Ukraine"])

# %% [markdown]
# ### Label Parts-of-Speech

# %%
from urllib import request

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Sondland.txt"
response = request.urlopen(url)
f1 = response.read().decode('utf8')

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Yovanovitch.txt"
response = request.urlopen(url)
f2 = response.read().decode('utf8')


import nltk, pprint
from nltk import word_tokenize

text = f2

#Tokenize text
tokenized_word=word_tokenize(text)
tok = nltk.Text(tokenized_word)

#Tag text using 12 universal POS tags
new2 = nltk.pos_tag(tok, tagset='universal')
#print(new2)

#Extract POS and add to list
final = []
for word, pos in new2:
    #print(word, pos)
    final.append(pos)
#print(final)

#Join list into single string
final2 = ' '.join(final)
#print(final2)

#Count POS
from collections import Counter
count = Counter([pos for word,pos in new2])
print(count)

#Calculate POS as percentage of total words

#f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

textWords = []
    
for word in tok:
    if word.isalpha():
        textWords.append(word)

tot_words = len(textWords)
print(tot_words)

NOUN = count['NOUN']/tot_words
VERB = count['VERB']/tot_words
ADP = count['ADP']/tot_words
DET = count['DET']/tot_words
PRON = count['PRON']/tot_words
ADJ = count['ADJ']/tot_words
ADV = count['ADV']/tot_words
CONJ = count['CONJ']/tot_words
PRT = count['PRT']/tot_words
NUM = count['NUM']/tot_words
X = count['X']/tot_words
print("Nouns: "+"{:.0%}".format(NOUN));
print("Verbs: "+"{:.0%}".format(VERB));
print("Adpositions: "+"{:.0%}".format(ADP));
print("Determiners: "+"{:.0%}".format(DET));
print("Pronouns: "+"{:.0%}".format(PRON));
print("Adverbs: "+"{:.0%}".format(ADV));
print("Adjectives: "+"{:.0%}".format(ADJ));
print("Conjunctions: "+"{:.0%}".format(CONJ));
print("Particles: "+"{:.0%}".format(PRT));
print("Numbers: "+"{:.0%}".format(NUM));
print("Other: "+"{:.0%}".format(X));
# Out:
# Counter({'NOUN': 815, 'VERB': 532, 'ADP': 356, 'DET': 317, '.': 287, 'PRON': 261, 'ADJ': 236, 'ADV': 163, 'CONJ': 128, 'PRT': 109, 'NUM': 34})
# 2883
# Nouns: 28%
# Verbs: 18%
# Adpositions: 12%
# Determiners: 11%
# Pronouns: 9%
# Adverbs: 6%
# Adjectives: 8%
# Conjunctions: 4%
# Particles: 4%
# Numbers: 1%
# Other: 0%

# %% [markdown]
# ### Sentiment Analysis
# - Technique for evaluating the positive or negative attitudes or emotions of a speaker
# - VADER (Valence Aware Dictionary and Sentiment Reasoner) is a pre-built lexicon of positive/negative words
# - You can build a customized sentiment analysis tool using machine learning
#
# - *Adapted from: https://medium.com/@sharonwoo/sentiment-analysis-with-nltk-422e0f794b8*

# %%
from nltk.tokenize import sent_tokenize
from urllib import request

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Sondland.txt"
response = request.urlopen(url)
f1 = response.read().decode('utf8')

url = "https://github.com/cmiya/DSCWorkshop/raw/master/Yovanovitch.txt"
response = request.urlopen(url)
f2 = response.read().decode('utf8')


text= f2
tokenized_text=sent_tokenize(text)
#print(tokenized_text)

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()

summary = {"positive":0,"neutral":0,"negative":0}
for x in tokenized_text:
    ss = sid.polarity_scores(x)
    #print(x)
    #print(ss)
    if ss["compound"] == 0.0: 
        summary["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary["positive"] +=1
    else:
        summary["negative"] +=1

total_wds = summary["neutral"] + summary["positive"] + summary["negative"]
#print(total_wds)

summary_fin = {"positive": "{0:.0%}".format(summary["neutral"]/total_wds),"neutral": "{0:.0%}".format(summary["positive"]/total_wds),"negative":"{0:.0%}".format(summary["negative"]/total_wds)}

print(summary_fin)
# Out:
# {'neutral': '50%', 'positive': '24%', 'negative': '26%'}
