# %% [markdown]
# # Intro to Text Analysis
#
# ## <font color='orange'>Workshop Description</font>
#
# This hands-on workshop will introduce students to the basics of text analysis using Python’s Natural Language Toolkit (NLTK) library. Students will learn how to search for patterns in a text and extract and summarize information about its features. This class is designed for beginners and will especially appeal to those in humanities fields.
#
# By the end of the workshop, students will know how to:
#
# - Setup and install required software
# - Load a text file
# - Clean up and tokenize a text
# - Search for words in context
# - Chart word frequency
# - Tag parts-of-speech
#
# ### Requirements:
# - Bring a laptop
# - Download the latest version of anaconda: (https://docs.anaconda.com/anaconda/install/)
# - If you already have an older version of anaconda installed, make sure to update it:  (https://docs.anaconda.com/anaconda/install/update-version/)
#
# ### Resources:
# - Getting Started with NLTK [(online)](https://www.nltk.org/book/ch01.html)
# - Data Camp's Beginner's Guide to NLTK [(online)](https://www.datacamp.com/community/tutorials/text-analytics-beginners-nltk)
# - Markdown Cheat Sheet [(online)](https://www.markdownguide.org/cheat-sheet/)
# - Programming Historian [(online)](https://programminghistorian.org/)

# %% [markdown]
# ## <font color='orange'>What is Text Analysis?</font>
# - Searching for patterns in a text
# - Comparative
# - What makes a feature significant?

# %% [markdown]
# ## <font color='orange'>What is Jupyter Notebook?</font>
#
# - Jupyter Notebook is a Graphic User Interface (GUI aka "gooey") that sits on top of the computer code and makes it easier to interact with.
# - Jupyter Notebook is for:
#     - a) writing and executing "live" computer code
#     - b) creating written and visual notes or commentary (like for tutorials!)
#
# ### Using Jupyter:
# - **Cells** are boxes for entering code or text.
# - Switch between **Cell Types** using the dropdown menu:
#     - a) **Code**: e.g. Python, Java, R
#     - b) **Markdown**: create text and visual content, easy-to-read and write
#
# ### Working with Cells
# - **Double-click** a Cell to edit it.
# - You can **Insert** Cells above or below, **Copy and Paste** Cells contents, **Move** Cells up/down, and **Delete** Cells.
# - Click **Shift + Return** to execute Cell contents (run code).
# - Click the **STOP** icon to stop (interrupt) code.

# %% [markdown]
# ## <font color='orange'>Getting Started with NLTK</font>
#
# ### Open Jupyter Notebook
# - Open Anaconda-Navigator (in Applications)
# - Under Home, click the 'Jupyter Notebook' icon to launch.

# %% [markdown]
# ### Import the NLTK Library

# %%
#Import the NLTK library 

import nltk
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/chelseamiya/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %% [markdown]
# ### Load Text from Text File

# %%
#Load text from a text file

f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

#raw = f1.read()
#print(raw)

# %% [markdown]
# ### Calculate number of words

# %%
#Compare the length of each testimony

len(f2.read())
# Out:
# 17339

# %% [markdown]
# ### Tokenize Words

# %%
#Tokenize words

from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(raw)
print(tokenized_word)
# Out:
# ['I', 'appreciate', 'the', 'opportunity', 'to', 'speak', 'again', 'to', 'the', 'members', 'of', 'this', 'committee', '.', 'First', ',', 'let', 'me', 'offer', 'my', 'thanks', 'to', 'the', 'men', 'and', 'women', 'of', 'the', 'US', 'Department', 'of', 'State', ',', 'who', 'have', 'committed', 'their', 'professional', 'lives', 'to', 'support', 'the', 'foreign', 'policy', 'work', 'of', 'the', 'United', 'States', '.', 'In', 'particular', ',', 'I', 'want', 'to', 'thank', 'my', 'staff', 'at', 'the', 'US', 'Mission', 'to', 'the', 'European', 'Union', '.', 'Your', 'integrity', ',', 'dedication', ',', 'and', 'hard', 'work', 'often', 'performed', 'without', 'public', 'acclaim', 'or', 'recognition', 'serve', 'as', 'a', 'shining', 'example', 'of', 'true', 'public', 'service', '.', 'And', 'I', 'am', 'personally', 'grateful', 'to', 'work', 'beside', 'you', 'each', 'and', 'every', 'day', '.', 'It', 'is', 'my', 'honor', 'to', 'serve', 'as', 'the', 'US', 'Ambassador', 'to', 'the', 'European', 'Union', '.', 'The', 'US', 'Mission', 'to', 'the', 'EU', 'is', 'the', 'direct', 'link', 'between', 'the', 'United', 'States', 'and', 'the', 'European', 'Union', 'and', 'its', 'members', '.', 'America', '’', 's', 'longest', 'standing', 'allies', 'and', 'one', 'of', 'the', 'largest', 'economic', 'blocks', 'in', 'the', 'world', '.', 'Every', 'day', 'I', 'work', 'to', 'support', 'a', 'strong', ',', 'united', 'and', 'peaceful', 'Europe', '.', 'Strengthening', 'our', 'ties', 'with', 'Europe', 'serves', 'both', 'American', 'and', 'European', 'goals', 'as', 'we', 'together', 'promote', 'political', 'stability', 'and', 'economic', 'prosperity', 'around', 'the', 'world', '.', 'I', 'expect', 'that', 'few', 'Americans', 'have', 'heard', 'my', 'name', 'before', 'these', 'events', '.', 'So', 'before', 'I', 'begin', 'my', 'substantive', 'testimony', ',', 'please', 'let', 'me', 'share', 'some', 'of', 'my', 'personal', 'background', '.', 'My', 'parents', 'fled', 'Europe', 'during', 'the', 'Holocaust', '.', 'Escaping', 'the', 'atrocities', 'of', 'that', 'time', ',', 'my', 'parents', 'left', 'Germany', 'for', 'Uruguay', 'and', 'then', 'in', '1953', 'emigrated', 'to', 'Seattle', ',', 'Washington', ',', 'where', 'I', 'was', 'born', 'and', 'raised', '.', 'Like', 'so', 'many', 'immigrants', ',', 'my', 'family', 'was', 'eager', 'for', 'freedom', 'and', 'hungry', 'for', 'opportunity', '.', 'They', 'raised', 'my', 'sister', 'and', 'me', 'to', 'be', 'humble', ',', 'hardworking', 'and', 'patriotic', 'and', 'I', 'am', 'forever', 'grateful', 'for', 'the', 'sacrifices', 'they', 'made', 'on', 'our', 'behalf', '.', 'Public', 'service', 'has', 'always', 'been', 'important', 'to', 'me', '.', 'As', 'a', 'lifelong', 'Republican', ',', 'I', 'have', 'contributed', 'to', 'initiatives', 'of', 'both', 'Republican', 'and', 'Democratic', 'administrations', '.', 'In', '2003', ',', 'I', 'served', 'as', 'a', 'member', 'of', 'the', 'transition', 'team', 'for', 'Oregon', 'Democratic', 'Governor', 'Ted', 'Kulongoski', '.', 'Governor', 'Kulongoski', 'also', 'appointed', 'me', 'to', 'serve', 'on', 'various', 'statewide', 'boards', '.', 'In', '2007', ',', 'President', 'George', 'W.', 'Bush', 'appointed', 'me', 'as', 'a', 'member', 'of', 'the', 'Commission', 'on', 'White', 'House', 'Fellows', '.', 'I', 'worked', 'with', 'President', 'Bush', 'on', 'charitable', 'events', 'for', 'his', 'foundation', '’', 's', 'military', 'service', 'initiative', '.', 'And', 'I', 'also', 'worked', 'briefly', 'with', 'former', 'Vice', 'President', 'Joe', 'Biden', '’', 's', 'office', 'in', 'connection', 'with', 'the', 'vice', 'president', '’', 's', 'nationwide', 'anti-cancer', 'initiative', 'at', 'a', 'local', 'Northwest', 'hospital', '.', 'And', 'of', 'course', 'the', 'highest', 'honor', 'in', 'my', 'public', 'life', 'came', 'when', 'President', 'Trump', 'asked', 'me', 'to', 'serve', 'as', 'the', 'United', 'States', 'Ambassador', 'to', 'the', 'European', 'Union', '.', 'The', 'Senate', 'confirmed', 'me', 'as', 'an', 'ambassador', ' ...

# %% [markdown]
# ### Clean up text

# %%
#Remove numbers and punctuation

#Create a empty "list" (like a bin) to put the words in
clean_text = []

#For each word that contains only numbers or letters, add it to the list
for word in tokenized_word:
    if word.isalpha():
        clean_text.append(word)

#Print the contents of our (now full) list
print(clean_text)

#Print the length of items in the list
len(clean_text)
# Out:
# ['I', 'appreciate', 'the', 'opportunity', 'to', 'speak', 'again', 'to', 'the', 'members', 'of', 'this', 'committee', 'First', 'let', 'me', 'offer', 'my', 'thanks', 'to', 'the', 'men', 'and', 'women', 'of', 'the', 'US', 'Department', 'of', 'State', 'who', 'have', 'committed', 'their', 'professional', 'lives', 'to', 'support', 'the', 'foreign', 'policy', 'work', 'of', 'the', 'United', 'States', 'In', 'particular', 'I', 'want', 'to', 'thank', 'my', 'staff', 'at', 'the', 'US', 'Mission', 'to', 'the', 'European', 'Union', 'Your', 'integrity', 'dedication', 'and', 'hard', 'work', 'often', 'performed', 'without', 'public', 'acclaim', 'or', 'recognition', 'serve', 'as', 'a', 'shining', 'example', 'of', 'true', 'public', 'service', 'And', 'I', 'am', 'personally', 'grateful', 'to', 'work', 'beside', 'you', 'each', 'and', 'every', 'day', 'It', 'is', 'my', 'honor', 'to', 'serve', 'as', 'the', 'US', 'Ambassador', 'to', 'the', 'European', 'Union', 'The', 'US', 'Mission', 'to', 'the', 'EU', 'is', 'the', 'direct', 'link', 'between', 'the', 'United', 'States', 'and', 'the', 'European', 'Union', 'and', 'its', 'members', 'America', 's', 'longest', 'standing', 'allies', 'and', 'one', 'of', 'the', 'largest', 'economic', 'blocks', 'in', 'the', 'world', 'Every', 'day', 'I', 'work', 'to', 'support', 'a', 'strong', 'united', 'and', 'peaceful', 'Europe', 'Strengthening', 'our', 'ties', 'with', 'Europe', 'serves', 'both', 'American', 'and', 'European', 'goals', 'as', 'we', 'together', 'promote', 'political', 'stability', 'and', 'economic', 'prosperity', 'around', 'the', 'world', 'I', 'expect', 'that', 'few', 'Americans', 'have', 'heard', 'my', 'name', 'before', 'these', 'events', 'So', 'before', 'I', 'begin', 'my', 'substantive', 'testimony', 'please', 'let', 'me', 'share', 'some', 'of', 'my', 'personal', 'background', 'My', 'parents', 'fled', 'Europe', 'during', 'the', 'Holocaust', 'Escaping', 'the', 'atrocities', 'of', 'that', 'time', 'my', 'parents', 'left', 'Germany', 'for', 'Uruguay', 'and', 'then', 'in', 'emigrated', 'to', 'Seattle', 'Washington', 'where', 'I', 'was', 'born', 'and', 'raised', 'Like', 'so', 'many', 'immigrants', 'my', 'family', 'was', 'eager', 'for', 'freedom', 'and', 'hungry', 'for', 'opportunity', 'They', 'raised', 'my', 'sister', 'and', 'me', 'to', 'be', 'humble', 'hardworking', 'and', 'patriotic', 'and', 'I', 'am', 'forever', 'grateful', 'for', 'the', 'sacrifices', 'they', 'made', 'on', 'our', 'behalf', 'Public', 'service', 'has', 'always', 'been', 'important', 'to', 'me', 'As', 'a', 'lifelong', 'Republican', 'I', 'have', 'contributed', 'to', 'initiatives', 'of', 'both', 'Republican', 'and', 'Democratic', 'administrations', 'In', 'I', 'served', 'as', 'a', 'member', 'of', 'the', 'transition', 'team', 'for', 'Oregon', 'Democratic', 'Governor', 'Ted', 'Kulongoski', 'Governor', 'Kulongoski', 'also', 'appointed', 'me', 'to', 'serve', 'on', 'various', 'statewide', 'boards', 'In', 'President', 'George', 'Bush', 'appointed', 'me', 'as', 'a', 'member', 'of', 'the', 'Commission', 'on', 'White', 'House', 'Fellows', 'I', 'worked', 'with', 'President', 'Bush', 'on', 'charitable', 'events', 'for', 'his', 'foundation', 's', 'military', 'service', 'initiative', 'And', 'I', 'also', 'worked', 'briefly', 'with', 'former', 'Vice', 'President', 'Joe', 'Biden', 's', 'office', 'in', 'connection', 'with', 'the', 'vice', 'president', 's', 'nationwide', 'initiative', 'at', 'a', 'local', 'Northwest', 'hospital', 'And', 'of', 'course', 'the', 'highest', 'honor', 'in', 'my', 'public', 'life', 'came', 'when', 'President', 'Trump', 'asked', 'me', 'to', 'serve', 'as', 'the', 'United', 'States', 'Ambassador', 'to', 'the', 'European', 'Union', 'The', 'Senate', 'confirmed', 'me', 'as', 'an', 'ambassador', 'on', 'a', 'bipartisan', 'voice', 'vote', 'and', 'I', 'assumed', 'the', 'role', 'in', 'Brussels', 'on', 'July', 'Although', 'today', 'is', 'my', 'first', 'public', 'testimony', 'on', 'the', 'Ukraine', 'matters', 'this', 'is', 'not', 'my', 'first', 'time', 'coop ...
# 5053

# %% [markdown]
# ### Calculate lexical diversity

# %%
#Calculate lexical diversity by...
#Dividing the total number of words by the number of unique words

len(set(word.lower() for word in clean_text)) / len(clean_text)
# Out:
# 0.22382742924995053

# %%
#What if you want to repeat a calculation on several texts?

#Create a FUNCTION to build a tool from a block of code

def lexical_diversity(text):

    textWords = []
    
    from nltk.tokenize import word_tokenize
    tokenized_word=word_tokenize(text)
    
    for word in tokenized_word:
        if word.isalpha():
            textWords.append(word)

    return len(set(word.lower() for word in textWords)) / len(textWords)

# %%
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

raw = f1.read()

lexical_diversity(raw)
# Out:
# 0.22382742924995053

# %% [markdown]
# ### Word Frequency

# %%
from nltk.probability import FreqDist
fdist = FreqDist(clean_text)
print(fdist)
# Out:
# <FreqDist with 0 samples and 0 outcomes>

# %%
fdist.most_common(2)
# Out:
# []

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %% [markdown]
# ### Eliminate Stopwords

# %%
from nltk.corpus import stopwords

stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'himself', 'on', 'more', 'mustn', 'having', 'until', 'have', 'couldn', 'me', 'above', 'she', 'an', 'then', 'his', 'had', 'o', 'there', 'against', 'ain', 'it', 'or', 'yourselves', 'but', 'out', 'of', 'whom', "you're", 'am', 'hers', 've', "mightn't", 'off', 'before', 'd', "isn't", 'themselves', 'these', 'ourselves', 'other', 'my', 'shouldn', "haven't", 'their', 'over', 'because', "that'll", 'any', 'at', 'myself', 'as', 'such', 'into', 'weren', 'no', 'what', "didn't", 'doesn', 'm', 'those', 'the', 'we', 'been', "it's", 'same', 'do', 'with', 'yours', 'hasn', 'does', 'down', "wasn't", 'wasn', 'i', 'which', 'him', 'below', 'her', 'nor', 'how', 'being', 'our', 'while', 's', "should've", 'only', "wouldn't", "doesn't", 'under', "shan't", 'from', 'when', 'he', 'won', 'not', 'that', 'for', "you've", 'between', 'can', 'yourself', 'has', 'who', "she's", "couldn't", 'each', 'again', 'too', 'further', 't', 'own', 'here', 'haven', 'during', 'are', 'y', 'mightn', 'all', 'this', 'isn', "aren't", 'why', 'now', 'needn', 'both', 'to', 'in', "don't", "mustn't", 'by', 'is', 'very', 'than', 'up', 'if', 'were', 're', 'after', 'was', 'itself', "you'll", 'shan', 'its', "hasn't", 'once', 'a', 'through', 'hadn', 'ma', 'you', 'didn', 'll', 'aren', 'ours', "needn't", 'did', 'your', "you'd", 'where', 'most', 'just', "hadn't", 'them', 'few', 'so', 'doing', 'they', "weren't", 'and', 'wouldn', 'some', "won't", 'should', 'herself', 'will', 'be', 'theirs', "shouldn't", 'about', 'don'}

# %%
filtered_word=[]
for w in clean_text:
    if w not in stop_words:
        filtered_word.append(w)
print("Tokenized Sentence:",tokenized_word)
print(len(tokenized_word))

print("Filtered Sentence:",filtered_word)
print(len(filtered_word))
# Out:
# Tokenized Sentence: ['I', 'appreciate', 'the', 'opportunity', 'to', 'speak', 'again', 'to', 'the', 'members', 'of', 'this', 'committee', '.', 'First', ',', 'let', 'me', 'offer', 'my', 'thanks', 'to', 'the', 'men', 'and', 'women', 'of', 'the', 'US', 'Department', 'of', 'State', ',', 'who', 'have', 'committed', 'their', 'professional', 'lives', 'to', 'support', 'the', 'foreign', 'policy', 'work', 'of', 'the', 'United', 'States', '.', 'In', 'particular', ',', 'I', 'want', 'to', 'thank', 'my', 'staff', 'at', 'the', 'US', 'Mission', 'to', 'the', 'European', 'Union', '.', 'Your', 'integrity', ',', 'dedication', ',', 'and', 'hard', 'work', 'often', 'performed', 'without', 'public', 'acclaim', 'or', 'recognition', 'serve', 'as', 'a', 'shining', 'example', 'of', 'true', 'public', 'service', '.', 'And', 'I', 'am', 'personally', 'grateful', 'to', 'work', 'beside', 'you', 'each', 'and', 'every', 'day', '.', 'It', 'is', 'my', 'honor', 'to', 'serve', 'as', 'the', 'US', 'Ambassador', 'to', 'the', 'European', 'Union', '.', 'The', 'US', 'Mission', 'to', 'the', 'EU', 'is', 'the', 'direct', 'link', 'between', 'the', 'United', 'States', 'and', 'the', 'European', 'Union', 'and', 'its', 'members', '.', 'America', '’', 's', 'longest', 'standing', 'allies', 'and', 'one', 'of', 'the', 'largest', 'economic', 'blocks', 'in', 'the', 'world', '.', 'Every', 'day', 'I', 'work', 'to', 'support', 'a', 'strong', ',', 'united', 'and', 'peaceful', 'Europe', '.', 'Strengthening', 'our', 'ties', 'with', 'Europe', 'serves', 'both', 'American', 'and', 'European', 'goals', 'as', 'we', 'together', 'promote', 'political', 'stability', 'and', 'economic', 'prosperity', 'around', 'the', 'world', '.', 'I', 'expect', 'that', 'few', 'Americans', 'have', 'heard', 'my', 'name', 'before', 'these', 'events', '.', 'So', 'before', 'I', 'begin', 'my', 'substantive', 'testimony', ',', 'please', 'let', 'me', 'share', 'some', 'of', 'my', 'personal', 'background', '.', 'My', 'parents', 'fled', 'Europe', 'during', 'the', 'Holocaust', '.', 'Escaping', 'the', 'atrocities', 'of', 'that', 'time', ',', 'my', 'parents', 'left', 'Germany', 'for', 'Uruguay', 'and', 'then', 'in', '1953', 'emigrated', 'to', 'Seattle', ',', 'Washington', ',', 'where', 'I', 'was', 'born', 'and', 'raised', '.', 'Like', 'so', 'many', 'immigrants', ',', 'my', 'family', 'was', 'eager', 'for', 'freedom', 'and', 'hungry', 'for', 'opportunity', '.', 'They', 'raised', 'my', 'sister', 'and', 'me', 'to', 'be', 'humble', ',', 'hardworking', 'and', 'patriotic', 'and', 'I', 'am', 'forever', 'grateful', 'for', 'the', 'sacrifices', 'they', 'made', 'on', 'our', 'behalf', '.', 'Public', 'service', 'has', 'always', 'been', 'important', 'to', 'me', '.', 'As', 'a', 'lifelong', 'Republican', ',', 'I', 'have', 'contributed', 'to', 'initiatives', 'of', 'both', 'Republican', 'and', 'Democratic', 'administrations', '.', 'In', '2003', ',', 'I', 'served', 'as', 'a', 'member', 'of', 'the', 'transition', 'team', 'for', 'Oregon', 'Democratic', 'Governor', 'Ted', 'Kulongoski', '.', 'Governor', 'Kulongoski', 'also', 'appointed', 'me', 'to', 'serve', 'on', 'various', 'statewide', 'boards', '.', 'In', '2007', ',', 'President', 'George', 'W.', 'Bush', 'appointed', 'me', 'as', 'a', 'member', 'of', 'the', 'Commission', 'on', 'White', 'House', 'Fellows', '.', 'I', 'worked', 'with', 'President', 'Bush', 'on', 'charitable', 'events', 'for', 'his', 'foundation', '’', 's', 'military', 'service', 'initiative', '.', 'And', 'I', 'also', 'worked', 'briefly', 'with', 'former', 'Vice', 'President', 'Joe', 'Biden', '’', 's', 'office', 'in', 'connection', 'with', 'the', 'vice', 'president', '’', 's', 'nationwide', 'anti-cancer', 'initiative', 'at', 'a', 'local', 'Northwest', 'hospital', '.', 'And', 'of', 'course', 'the', 'highest', 'honor', 'in', 'my', 'public', 'life', 'came', 'when', 'President', 'Trump', 'asked', 'me', 'to', 'serve', 'as', 'the', 'United', 'States', 'Ambassador', 'to', 'the', 'European', 'Union', '.', 'The', 'Senate', 'confirmed', 'me', 'as', ' ...
# 5919
# Filtered Sentence: ['I', 'appreciate', 'opportunity', 'speak', 'members', 'committee', 'First', 'let', 'offer', 'thanks', 'men', 'women', 'US', 'Department', 'State', 'committed', 'professional', 'lives', 'support', 'foreign', 'policy', 'work', 'United', 'States', 'In', 'particular', 'I', 'want', 'thank', 'staff', 'US', 'Mission', 'European', 'Union', 'Your', 'integrity', 'dedication', 'hard', 'work', 'often', 'performed', 'without', 'public', 'acclaim', 'recognition', 'serve', 'shining', 'example', 'true', 'public', 'service', 'And', 'I', 'personally', 'grateful', 'work', 'beside', 'every', 'day', 'It', 'honor', 'serve', 'US', 'Ambassador', 'European', 'Union', 'The', 'US', 'Mission', 'EU', 'direct', 'link', 'United', 'States', 'European', 'Union', 'members', 'America', 'longest', 'standing', 'allies', 'one', 'largest', 'economic', 'blocks', 'world', 'Every', 'day', 'I', 'work', 'support', 'strong', 'united', 'peaceful', 'Europe', 'Strengthening', 'ties', 'Europe', 'serves', 'American', 'European', 'goals', 'together', 'promote', 'political', 'stability', 'economic', 'prosperity', 'around', 'world', 'I', 'expect', 'Americans', 'heard', 'name', 'events', 'So', 'I', 'begin', 'substantive', 'testimony', 'please', 'let', 'share', 'personal', 'background', 'My', 'parents', 'fled', 'Europe', 'Holocaust', 'Escaping', 'atrocities', 'time', 'parents', 'left', 'Germany', 'Uruguay', 'emigrated', 'Seattle', 'Washington', 'I', 'born', 'raised', 'Like', 'many', 'immigrants', 'family', 'eager', 'freedom', 'hungry', 'opportunity', 'They', 'raised', 'sister', 'humble', 'hardworking', 'patriotic', 'I', 'forever', 'grateful', 'sacrifices', 'made', 'behalf', 'Public', 'service', 'always', 'important', 'As', 'lifelong', 'Republican', 'I', 'contributed', 'initiatives', 'Republican', 'Democratic', 'administrations', 'In', 'I', 'served', 'member', 'transition', 'team', 'Oregon', 'Democratic', 'Governor', 'Ted', 'Kulongoski', 'Governor', 'Kulongoski', 'also', 'appointed', 'serve', 'various', 'statewide', 'boards', 'In', 'President', 'George', 'Bush', 'appointed', 'member', 'Commission', 'White', 'House', 'Fellows', 'I', 'worked', 'President', 'Bush', 'charitable', 'events', 'foundation', 'military', 'service', 'initiative', 'And', 'I', 'also', 'worked', 'briefly', 'former', 'Vice', 'President', 'Joe', 'Biden', 'office', 'connection', 'vice', 'president', 'nationwide', 'initiative', 'local', 'Northwest', 'hospital', 'And', 'course', 'highest', 'honor', 'public', 'life', 'came', 'President', 'Trump', 'asked', 'serve', 'United', 'States', 'Ambassador', 'European', 'Union', 'The', 'Senate', 'confirmed', 'ambassador', 'bipartisan', 'voice', 'vote', 'I', 'assumed', 'role', 'Brussels', 'July', 'Although', 'today', 'first', 'public', 'testimony', 'Ukraine', 'matters', 'first', 'time', 'cooperating', 'committee', 'As', 'know', 'I', 'already', 'provided', 'hours', 'deposition', 'testimony', 'And', 'I', 'despite', 'directives', 'White', 'House', 'State', 'Department', 'I', 'refused', 'appear', 'many', 'others', 'done', 'I', 'agreed', 'testify', 'I', 'respect', 'gravity', 'moment', 'I', 'believe', 'I', 'obligation', 'account', 'fully', 'role', 'events', 'But', 'I', 'also', 'must', 'acknowledge', 'process', 'challenging', 'And', 'many', 'respects', 'less', 'fair', 'I', 'access', 'phone', 'records', 'State', 'Department', 'emails', 'many', 'many', 'State', 'Department', 'documents', 'And', 'I', 'told', 'I', 'could', 'work', 'EU', 'staff', 'pull', 'together', 'relevant', 'files', 'information', 'Having', 'access', 'State', 'Department', 'materials', 'would', 'helpful', 'trying', 'reconstruct', 'I', 'spoke', 'met', 'said', 'As', 'ambassador', 'I', 'hundreds', 'meetings', 'calls', 'individuals', 'I', 'note', 'taker', 'memo', 'writer', 'Never', 'My', 'job', 'requires', 'I', 'speak', 'heads', 'state', 'senior', 'government', 'officials', 'members', 'cabinet', 'president', 'almost', 'every', 'day', 'Talking', 'foreign', 'leaders', 'might', 'memorable', 'people', 'job',  ...
# 2937

# %% [markdown]
# ### Plot Frequency Distibution

# %%
from nltk.probability import FreqDist
fdist = FreqDist(filtered_word)
print(fdist)

# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()
# Out:
# <FreqDist with 1127 samples and 2937 outcomes>

# %% [markdown]
# ### Find words in context

# %%
##Find word concordance for raw text

text = nltk.Text(clean_text)
text.concordance('Trump')
# Out:
# Displaying 23 of 23 matches:
# n my public life came when President Trump asked me to serve as the United Stat
# hite House on May to brief President Trump We advised the president of the stra
# orking phone call between Presidents Trump and Zelensky and second a working ov
# cy interests Unfortunately President Trump was skeptical He expressed concerns
# eeting to change his views President Trump directed us to talk with We understo
# White House visit between Presidents Trump and Zelensky which was unquestionabl
# interest or we could do as President Trump had directed and talk with Rudy We c
# ite House meeting between Presidents Trump and Zelensky From my perspective the
# ainians that would satisfy President Trump s concerns For example on July and t
# allenges we faced On July Presidents Trump and Zelensky had their official call
# ly after the call between Presidents Trump in Zelensky was entirely entirely co
# ance of his July call with President Trump nor did he discuss any request inves
# ings I spoke by phone with President Trump The White House which has finally fi
# igations were important to President Trump We did not discuss any classified in
# ave been more surprised if President Trump had not mentioned investigations par
# dor Volker and others that President Trump wanted a public statement from Presi
# te House meeting reflected President Trump s desires and requirements Reflected
# and requirements Reflected President Trump s desires and requirements Within my
# necessary in his call with President Trump On July in a WhatsApp message betwee
# ompeo whether a conversation between Trump and Zelensky would help to break the
# e logjam and this was when President Trump was still intending to travel to War
# ky in Warsaw Unfortunately President Trump s attendance at the Warsaw meeting w
# aid that he would speak to President Trump about it Based on my previous commun

# %%
#Find words that appear in similar contexts

text.similar("July")
# Out:
# august front kyiv actual february june any brussels zelensky
# presidential warsaw september may

# %% [markdown]
# ### Plot Lexical Dispertion
# - Compare how different words are distributed over the text

# %%
text.dispersion_plot(["US", "Trump", "public", "my", "aid", "Ukraine"])

# %% [markdown]
# ### Label Parts-of-Speech

# %%
#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

import nltk, pprint
from nltk import word_tokenize

text = f2

#Tokenize text
tokenized_word=word_tokenize(text.read())
tok = nltk.Text(tokenized_word)

#Tag text using 12 universal POS tags
new2 = nltk.pos_tag(tok, tagset='universal')
#print(new2)

#Extract POS and add to list
final = []
for word, pos in new2:
    #print(word, pos)
    final.append(pos)
#print(final)

#Join list into single string
final2 = ' '.join(final)
#print(final2)

#Count POS
from collections import Counter
count = Counter([pos for word,pos in new2])
print(count)

#Calculate POS as percentage of total words

#f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

textWords = []
    
for word in tok:
    if word.isalpha():
        textWords.append(word)

tot_words = len(textWords)
print(tot_words)

NOUN = count['NOUN']/tot_words
VERB = count['VERB']/tot_words
ADP = count['ADP']/tot_words
DET = count['DET']/tot_words
PRON = count['PRON']/tot_words
ADJ = count['ADJ']/tot_words
ADV = count['ADV']/tot_words
CONJ = count['CONJ']/tot_words
PRT = count['PRT']/tot_words
NUM = count['NUM']/tot_words
X = count['X']/tot_words
print("Nouns: "+"{:.0%}".format(NOUN));
print("Verbs: "+"{:.0%}".format(VERB));
print("Adpositions: "+"{:.0%}".format(ADP));
print("Determiners: "+"{:.0%}".format(DET));
print("Pronouns: "+"{:.0%}".format(PRON));
print("Adverbs: "+"{:.0%}".format(ADV));
print("Adjectives: "+"{:.0%}".format(ADJ));
print("Conjunctions: "+"{:.0%}".format(CONJ));
print("Particles: "+"{:.0%}".format(PRT));
print("Numbers: "+"{:.0%}".format(NUM));
print("Other: "+"{:.0%}".format(X));
# Out:
# Counter({'NOUN': 815, 'VERB': 532, 'ADP': 356, 'DET': 317, '.': 287, 'PRON': 261, 'ADJ': 236, 'ADV': 163, 'CONJ': 128, 'PRT': 109, 'NUM': 34})
# 2883
# Nouns: 28%
# Verbs: 18%
# Adpositions: 12%
# Determiners: 11%
# Pronouns: 9%
# Adverbs: 6%
# Adjectives: 8%
# Conjunctions: 4%
# Particles: 4%
# Numbers: 1%
# Other: 0%
