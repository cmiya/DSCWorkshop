# %%
import nltk

#Load text from a text file

f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

# %%
#Create a FUNCTION to tokenize texts

def tokenize(text):
    from nltk.tokenize import word_tokenize
    tokenized_word=word_tokenize(text.read())
    return nltk.Text(tokenized_word)

# %%
#Create a FUNCTION to remove punctuation:

def clean_up(text):
    
    #Call Tokenize FUNCTION
    text2 = tokenize(text)

    #Create a empty "list" (like a bin) to put the words in
    clean_text = []
    #For each word that contains only numbers or letters, add it to the list
    for word in text2:
        if word.isalpha():
            clean_text.append(word)

    #Print the contents of our (now full) list
    return clean_text

    #Print the length of items in the list
    #print(len(clean_text))

# %%
#Create a FUNCTION to calculate lexical diversity

def lexical_diversity(text):

    textWords = []
    
    text2 = tokenize(text)
    
    for word in text2:
        if word.isalpha():
            textWords.append(word)

    return len(set(word.lower() for word in textWords)) / len(textWords)

# %%
#Create a FUNCTION to filter Stop Words

def filter_stop(text):
    from nltk.corpus import stopwords
    stop_words=set(stopwords.words("english"))
    #print(stop_words)
    
    filtered_text=[]
    final = clean_up(text)
    for w in final:
        if w not in stop_words:
            filtered_text.append(w)
    
    return filtered_text
    print(len(filtered_text))

# %%
#Create a FUNCTION to calculate Word Frequency

def word_frequency(text):
    
    from nltk.probability import FreqDist
    filter2 = filter_stop(text)
    fdist = FreqDist(filter2)
    #print(fdist)
    
    # Frequency Distribution Plot
    import matplotlib.pyplot as plt
    fdist.plot(30,cumulative=False)
    return plt.show()

# %%
#Call FUNCTION

word_frequency(f1)

# %%
#Call FUNCTION

word_frequency(f2)

# %%
#Create a FUNCTION to calculate concordance

def word_concord(text, word):
    text2 = tokenize(text)
    text2.concordance(word)

# %%
#Create a FUNCTION to find words that appear in similar contexts

def word_similar(text, word):
    text2 = tokenize(text)
    text2.similar(word)

# %%
#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

#CALL FUNCTION

word_similar(f2, 'Trump')
# Out:
# previous obama smear clinton reagan

# %%
#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

#CALL FUNCTION

word_concord(f2, 'Trump')
# Out:
# Displaying 5 of 5 matches:
# war against Russia in 2014 , and the Trump administration strengthened our poli
# ubsequent resignation from President Trump ’ s campaign , and the departure fro
# om Ukraine . These include President Trump ’ s July 25th , 2019 call with Presi
# rainian officials that President ’ s Trump ’ s orders should be ignored because
# elp the Clinton campaign or harm the Trump campaign , nor would I have taken an

# %%
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

#Compare Lexical Dispersion Plot

tokenize(f1).dispersion_plot(["Trump", "Ukraine", "Russia", "I"])
tokenize(f2).dispersion_plot(["Trump", "Ukraine", "Russia", "I"])

# %%
#Parts of Speech Tagging

#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

nltk.pos_tag(tokenize(f1))
# Out:
# [('I', 'PRP'),
#  ('appreciate', 'VBP'),
#  ('the', 'DT'),
#  ('opportunity', 'NN'),
#  ('to', 'TO'),
#  ('speak', 'VB'),
#  ('again', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('First', 'NNP'),
#  (',', ','),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('offer', 'VB'),
#  ('my', 'PRP$'),
#  ('thanks', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('men', 'NNS'),
#  ('and', 'CC'),
#  ('women', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('Department', 'NNP'),
#  ('of', 'IN'),
#  ('State', 'NNP'),
#  (',', ','),
#  ('who', 'WP'),
#  ('have', 'VBP'),
#  ('committed', 'VBN'),
#  ('their', 'PRP$'),
#  ('professional', 'JJ'),
#  ('lives', 'NNS'),
#  ('to', 'TO'),
#  ('support', 'VB'),
#  ('the', 'DT'),
#  ('foreign', 'JJ'),
#  ('policy', 'NN'),
#  ('work', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('particular', 'JJ'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('thank', 'VB'),
#  ('my', 'PRP$'),
#  ('staff', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('Mission', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ('.', '.'),
#  ('Your', 'PRP$'),
#  ('integrity', 'NN'),
#  (',', ','),
#  ('dedication', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('hard', 'JJ'),
#  ('work', 'NN'),
#  ('often', 'RB'),
#  ('performed', 'VBN'),
#  ('without', 'IN'),
#  ('public', 'JJ'),
#  ('acclaim', 'NN'),
#  ('or', 'CC'),
#  ('recognition', 'NN'),
#  ('serve', 'VBP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('shining', 'VBG'),
#  ('example', 'NN'),
#  ('of', 'IN'),
#  ('true', 'JJ'),
#  ('public', 'JJ'),
#  ('service', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('personally', 'RB'),
#  ('grateful', 'JJ'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('beside', 'RB'),
#  ('you', 'PRP'),
#  ('each', 'DT'),
#  ('and', 'CC'),
#  ('every', 'DT'),
#  ('day', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('honor', 'NN'),
#  ('to', 'TO'),
#  ('serve', 'VB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('US', 'NNP'),
#  ('Ambassador', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('US', 'NNP'),
#  ('Mission', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('EU', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('direct', 'JJ'),
#  ('link', 'NN'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ('and', 'CC'),
#  ('its', 'PRP$'),
#  ('members', 'NNS'),
#  ('.', '.'),
#  ('America', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('longest', 'JJS'),
#  ('standing', 'VBG'),
#  ('allies', 'NNS'),
#  ('and', 'CC'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('largest', 'JJS'),
#  ('economic', 'JJ'),
#  ('blocks', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('.', '.'),
#  ('Every', 'DT'),
#  ('day', 'NN'),
#  ('I', 'PRP'),
#  ('work', 'VBP'),
#  ('to', 'TO'),
#  ('support', 'VB'),
#  ('a', 'DT'),
#  ('strong', 'JJ'),
#  (',', ','),
#  ('united', 'JJ'),
#  ('and', 'CC'),
#  ('peaceful', 'JJ'),
#  ('Europe', 'NNP'),
#  ('.', '.'),
#  ('Strengthening', 'VBG'),
#  ('our', 'PRP$'),
#  ('ties', 'NNS'),
#  ('with', 'IN'),
#  ('Europe', 'NNP'),
#  ('serves', 'VBZ'),
#  ('both', 'DT'),
#  ('American', 'NNP'),
#  ('and', 'CC'),
#  ('European', 'JJ'),
#  ('goals', 'NNS'),
#  ('as', 'IN'),
#  ('we', 'PRP'),
#  ('together', 'VBP'),
#  ('promote', 'JJ'),
#  ('political', 'JJ'),
#  ('stability', 'NN'),
#  ('and', 'CC'),
#  ('economic', 'JJ'),
#  ('prosperity', 'NN'),
#  ('around', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('expect', 'VBP'),
#  ('that', 'IN'),
#  ('few', 'JJ'),
#  ('Americans', 'NNPS'),
#  ('have', 'VBP'),
#  ('heard', 'VBN'),
#  ('my', 'PRP$'),
#  ('name', 'NN'),
#  ('before', 'IN'),
#  ('these', 'DT'),
#  ('events', 'NNS'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('before', 'IN'),
#  ('I', 'PRP'),
#  ('begin', 'VBP'),
#  ('my', 'PRP$'),
#  ('substantive', 'JJ'),
#  ('testimony', 'NN'),
#  (',', ','),
#  ('please', 'VB'),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('share', 'NN'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('personal', 'JJ'),
#  ('background', 'NN'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('parents', 'NNS'),
#  ('fled', 'VBN'),
#  ('Europe', 'NNP'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('Holocaust', 'NNP'),
#  ('.', '.'),
#  ('Escaping', 'VBG'),
#  ('the', 'DT'),
#  ('atrocities', 'NNS'),
#  ('of', 'IN'),
#  ('that', 'DT'),
#  ('time', 'NN'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('parents', 'NNS'),
#  ('left', 'VBD'),
#  ('Germany', 'NNP'),
#  ('for', 'IN'),
#  ('Uruguay', 'NNP'),
#  ('and', 'CC'),
#  ('then', 'RB'),
#  ('in', 'IN'),
#  ('1953', 'CD'),
#  ('emigrated', 'VBD'),
#  ('to', 'TO'),
#  ('Seattle', 'NNP'),
#  (',', ','),
#  ('Washington', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('born', 'VBN'),
#  ('and', 'CC'),
#  ('raised', 'VBN'),
#  ('.', '.'),
#  ('Like', 'IN'),
#  ('so', 'RB'),
#  ('many', 'JJ'),
#  ('immigrants', 'NNS'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('family', 'NN'),
#  ('was', 'VBD'),
#  ('eager', 'JJ'),
#  ('for', 'IN'),
#  ('freedom', 'NN'),
#  ('and', 'CC'),
#  ('hungry', 'NN'),
#  ('for', 'IN'),
#  ('opportunity', 'NN'),
#  ('.', '.'),
#  ('They', 'PRP'),
#  ('raised', 'VBD'),
#  ('my', 'PRP$'),
#  ('sister', 'NN'),
#  ('and', 'CC'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('humble', 'JJ'),
#  (',', ','),
#  ('hardworking', 'VBG'),
#  ('and', 'CC'),
#  ('patriotic', 'JJ'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('forever', 'RB'),
#  ('grateful', 'JJ'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('sacrifices', 'NNS'),
#  ('they', 'PRP'),
#  ('made', 'VBD'),
#  ('on', 'IN'),
#  ('our', 'PRP$'),
#  ('behalf', 'NN'),
#  ('.', '.'),
#  ('Public', 'NNP'),
#  ('service', 'NN'),
#  ('has', 'VBZ'),
#  ('always', 'RB'),
#  ('been', 'VBN'),
#  ('important', 'JJ'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('a', 'DT'),
#  ('lifelong', 'JJ'),
#  ('Republican', 'NNP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('contributed', 'VBN'),
#  ('to', 'TO'),
#  ('initiatives', 'NNS'),
#  ('of', 'IN'),
#  ('both', 'DT'),
#  ('Republican', 'NNP'),
#  ('and', 'CC'),
#  ('Democratic', 'JJ'),
#  ('administrations', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2003', 'CD'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('served', 'VBD'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('transition', 'NN'),
#  ('team', 'NN'),
#  ('for', 'IN'),
#  ('Oregon', 'NNP'),
#  ('Democratic', 'NNP'),
#  ('Governor', 'NNP'),
#  ('Ted', 'NNP'),
#  ('Kulongoski', 'NNP'),
#  ('.', '.'),
#  ('Governor', 'NNP'),
#  ('Kulongoski', 'NNP'),
#  ('also', 'RB'),
#  ('appointed', 'VBD'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('serve', 'VB'),
#  ('on', 'IN'),
#  ('various', 'JJ'),
#  ('statewide', 'JJ'),
#  ('boards', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2007', 'CD'),
#  (',', ','),
#  ('President', 'NNP'),
#  ('George', 'NNP'),
#  ('W.', 'NNP'),
#  ('Bush', 'NNP'),
#  ('appointed', 'VBD'),
#  ('me', 'PRP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Commission', 'NNP'),
#  ('on', 'IN'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('Fellows', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('worked', 'VBD'),
#  ('with', 'IN'),
#  ('President', 'NNP'),
#  ('Bush', 'NNP'),
#  ('on', 'IN'),
#  ('charitable', 'JJ'),
#  ('events', 'NNS'),
#  ('for', 'IN'),
#  ('his', 'PRP$'),
#  ('foundation', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('military', 'JJ'),
#  ('service', 'NN'),
#  ('initiative', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('also', 'RB'),
#  ('worked', 'VBD'),
#  ('briefly', 'NN'),
#  ('with', 'IN'),
#  ('former', 'JJ'),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('Joe', 'NNP'),
#  ('Biden', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'JJ'),
#  ('office', 'NN'),
#  ('in', 'IN'),
#  ('connection', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('vice', 'NN'),
#  ('president', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('nationwide', 'JJ'),
#  ('anti-cancer', 'JJ'),
#  ('initiative', 'NN'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('local', 'JJ'),
#  ('Northwest', 'NNP'),
#  ('hospital', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('of', 'IN'),
#  ('course', 'NN'),
#  ('the', 'DT'),
#  ('highest', 'JJS'),
#  ('honor', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('public', 'JJ'),
#  ('life', 'NN'),
#  ('came', 'VBD'),
#  ('when', 'WRB'),
#  ('President', 'NNP'),
#  ('Trump', 'NNP'),
#  ('asked', 'VBD'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('serve', 'VB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('Ambassador', 'NNP'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('European', 'NNP'),
#  ('Union', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Senate', 'NNP'),
#  ('confirmed', 'VBD'),
#  ('me', 'PRP'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('ambassador', 'NN'),
#  ('on', 'IN'),
#  ('a', 'DT'),
#  ('bipartisan', 'JJ'),
#  ('voice', 'NN'),
#  ('vote', 'NN'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('assumed', 'VBD'),
#  ('the', 'DT'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('Brussels', 'NNP'),
#  ('on', 'IN'),
#  ('July', 'NNP'),
#  ('9th', 'CD'),
#  (',', ','),
#  ('2018', 'CD'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('today', 'NN'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('first', 'JJ'),
#  ('public', 'JJ'),
#  ('testimony', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('Ukraine', 'NNP'),
#  ('matters', 'NNS'),
#  (',', ','),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('my', 'PRP$'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('cooperating', 'VBG'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('you', 'PRP'),
#  ('know', 'VBP'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('ve', 'JJ'),
#  ('already', 'RB'),
#  ('provided', 'VBD'),
#  ('10', 'CD'),
#  ('hours', 'NNS'),
#  ('of', 'IN'),
#  ('deposition', 'NN'),
#  ('testimony', 'NN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('did', 'VBD'),
#  ('so', 'RB'),
#  ('despite', 'IN'),
#  ('directives', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('refused', 'VBD'),
#  ('to', 'TO'),
#  ('appear', 'VB'),
#  ('as', 'IN'),
#  ('many', 'JJ'),
#  ('others', 'NNS'),
#  ('have', 'VBP'),
#  ('done', 'VBN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('agreed', 'VBD'),
#  ('to', 'TO'),
#  ('testify', 'VB'),
#  ('because', 'IN'),
#  ('I', 'PRP'),
#  ('respect', 'VBP'),
#  ('the', 'DT'),
#  ('gravity', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('moment', 'NN'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('believe', 'VBP'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('an', 'DT'),
#  ('obligation', 'NN'),
#  ('to', 'TO'),
#  ('account', 'VB'),
#  ('fully', 'RB'),
#  ('for', 'IN'),
#  ('my', 'PRP$'),
#  ('role', 'NN'),
#  ('in', 'IN'),
#  ('these', 'DT'),
#  ('events', 'NNS'),
#  ('.', '.'),
#  ('But', 'CC'),
#  ('I', 'PRP'),
#  ('also', 'RB'),
#  ('must', 'MD'),
#  ('acknowledge', 'VB'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('process', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('challenging', 'VBG'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('in', 'IN'),
#  ('many', 'JJ'),
#  ('respects', 'NNS'),
#  (',', ','),
#  ('less', 'JJR'),
#  ('than', 'IN'),
#  ('fair', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('not', 'RB'),
#  ('had', 'VBN'),
#  ('access', 'NN'),
#  ('to', 'TO'),
#  ('all', 'DT'),
#  ('of', 'IN'),
#  ('my', 'PRP$'),
#  ('phone', 'NN'),
#  ('records', 'NNS'),
#  (',', ','),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('emails', 'NNS'),
#  ('and', 'CC'),
#  ('many', 'JJ'),
#  (',', ','),
#  ('many', 'JJ'),
#  ('other', 'JJ'),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('documents', 'NNS'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('was', 'VBD'),
#  ('told', 'VBN'),
#  ('I', 'PRP'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('work', 'VB'),
#  ('with', 'IN'),
#  ('my', 'PRP$'),
#  ('EU', 'JJ'),
#  ('staff', 'NN'),
#  ('to', 'TO'),
#  ('pull', 'VB'),
#  ('together', 'RB'),
#  ('the', 'DT'),
#  ('relevant', 'JJ'),
#  ('files', 'NNS'),
#  ('and', 'CC'),
#  ('information', 'NN'),
#  ('.', '.'),
#  ('Having', 'VBG'),
#  ('access', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('materials', 'NNS'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('very', 'RB'),
#  ('helpful', 'JJ'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('in', 'IN'),
#  ('trying', 'VBG'),
#  ('to', 'TO'),
#  ('reconstruct', 'VB'),
#  ('with', 'IN'),
#  ('whom', 'WP'),
#  ('I', 'PRP'),
#  ('spoke', 'VBD'),
#  ('and', 'CC'),
#  ('met', 'VBD'),
#  ('and', 'CC'),
#  ('when', 'WRB'),
#  ('and', 'CC'),
#  ('what', 'WP'),
#  ('was', 'VBD'),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('ambassador', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('ve', 'NNS'),
#  ('had', 'VBD'),
#  ('hundreds', 'NNS'),
#  ('of', 'IN'),
#  ('meetings', 'NNS'),
#  ('and', 'CC'),
#  ('calls', 'VBZ'),
#  ('with', 'IN'),
#  ('individuals', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('not', 'RB'),
#  ('a', 'DT'),
#  ('note', 'NN'),
#  ('taker', 'NN'),
#  ('or', 'CC'),
#  ('a', 'DT'),
#  ('memo', 'JJ'),
#  ('writer', 'NN'),
#  ('.', '.'),
#  ('Never', 'WDT'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('job', 'NN'),
#  ('requires', 'VBZ'),
#  ('that', 'IN'),
#  ('I', 'PRP'),
#  ('speak', 'VBP'),
#  ('with', 'IN'),
#  ('heads', 'NNS'),
#  ('of', 'IN'),
#  ('state', 'NN'),
#  (',', ','),
#  ('senior', 'JJ'),
#  ('government', 'NN'),
#  ('officials', 'NNS'),
#  (',', ','),
#  ('members', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('cabinet', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('president', 'NN'),
#  ('almost', 'RB'),
#  ('each', 'DT'),
#  ('and', 'CC'),
#  ('every', 'DT'),
#  ('day', 'NN'),
#  ('.', '.'),
#  ('Talking', 'VBG'),
#  ('with', 'IN'),
#  ('foreign', 'JJ'),
#  ('leaders', 'NNS'),
#  ('might', 'MD'),
#  ('be', 'VB'),
#  ('memorable', 'JJ'),
#  ('to', 'TO'),
#  ('some', 'DT'),
#  ('people', 'NNS'),
#  (',', ','),
#  ('but', 'CC'),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('job', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('do', 'VBP'),
#  ('it', 'PRP'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('My', 'PRP$'),
#  ('lawyers', 'NNS'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('made', 'VBN'),
#  ('multiple', 'JJ'),
#  ('requests', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('White', 'NNP'),
#  ('House', 'NNP'),
#  ('for', 'IN'),
#  ('these', 'DT'),
#  ('materials', 'NNS'),
#  ('.', '.'),
#  ('Yet', 'CC'),
#  ('these', 'DT'),
#  ('materials', 'NNS'),
#  ('were', 'VBD'),
#  ('not', 'RB'),
#  ('provided', 'VBN'),
#  ('to', 'TO'),
#  ('me', 'PRP'),
#  ('and', 'CC'),
#  ('they', 'PRP'),
#  ('have', 'VBP'),
#  ('also', 'RB'),
#  ('refused', 'VBN'),
#  ('to', 'TO'),
#  ('share', 'NN'),
#  ('these', 'DT'),
#  ('materials', 'NNS'),
#  ('with', 'IN'),
#  ('this', 'DT'),
#  ('committee', 'NN'),
#  ('.', '.'),
#  ('These', 'DT'),
#  ('documents', 'NNS'),
#  ('are', 'VBP'),
#  ('not', 'RB'),
#  ('classified', 'VBN'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('in', 'IN'),
#  ('fairness', 'NN'),
#  ('should', 'MD'),
#  ('have', 'VB'),
#  ('been', 'VBN'),
#  ('made', 'VBN'),
#  ('available', 'JJ'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('absence', 'NN'),
#  ('of', 'IN'),
#  ('these', 'DT'),
#  ('materials', 'NNS'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('memory', 'NN'),
#  (',', ','),
#  ('admittedly', 'RB'),
#  (',', ','),
#  ('has', 'VBZ'),
#  ('not', 'RB'),
#  ('been', 'VBN'),
#  ('perfect', 'JJ'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('no', 'DT'),
#  ('doubt', 'NN'),
#  ('that', 'IN'),
#  ('a', 'DT'),
#  ('more', 'RBR'),
#  ('fair', 'JJ'),
#  (',', ','),
#  ('open', 'JJ'),
#  ('and', 'CC'),
#  ('orderly', 'JJ'),
#  ('process', 'NN'),
#  ('of', 'IN'),
#  ('allowing', 'VBG'),
#  ('me', 'PRP'),
#  ('to', 'TO'),
#  ('read', 'VB'),
#  ('the', 'DT'),
#  ('State', 'NNP'),
#  ('Department', 'NNP'),
#  ('records', 'NNS'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('materials', 'NNS'),
#  ('would', 'MD'),
#  ('have', 'VB'),
#  ('made', 'VBN'),
#  ('this', 'DT'),
#  ('process', 'NN'),
#  ('far', 'RB'),
#  ('more', 'RBR'),
#  ('transparent', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('don', 'VBP'),
#  ('’', 'JJ'),
#  ('t', 'JJ'),
#  ('intend', 'NN'),
#  ('to', 'TO'),
#  ('repeat', 'VB'),
#  ('my', 'PRP$'),
#  ('prior', 'JJ'),
#  ('opening', 'JJ'),
#  ('statement', 'NN'),
#  ('or', 'CC'),
#  ('attempt', 'NN'),
#  ('to', 'TO'),
#  ('summarize', 'VB'),
#  ('10', 'CD'),
#  ('hours', 'NNS'),
#  ('of', 'IN'),
#  ('previous', 'JJ'),
#  ('deposition', 'NN'),
#  ('testimony', 'NN'),
#  ('.', '.'),
#  ('However', 'RB'),
#  (',', ','),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('critical', 'JJ'),
#  ('points', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('obscured', 'VBN'),
#  ('by', 'IN'),
#  ('noise', 'NN'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('last', 'JJ'),
#  ('few', 'JJ'),
#  ('days', 'NNS'),
#  ('and', 'CC'),
#  ('weeks', 'NNS'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('worried', 'VBN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('bigger', 'JJR'),
#  ('picture', 'NN'),
#  ('is', 'VBZ'),
#  ('being', 'VBG'),
#  ('ignored', 'VBN'),
#  ('.', '.'),
#  ('So', 'RB'),
#  ('let', 'VB'),
#  ('me', 'PRP'),
#  ('make', 'VB'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('key', 'JJ'),
#  ('points', 'NNS'),
#  ('.', '.'),
#  ('First', 'NNP'),
#  (',', ','),
#  ('Secretary', 'NNP'),
#  ('Perry', 'NNP'),
#  (',', ','),
#  ('Ambassador', 'NNP'),
#  ('Volker', 'NNP'),
#  ('and', 'CC'),
#  ('I', 'PRP'),
#  ('worked', 'VBD'),
#  ('with', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Rudy', 'NNP'),
#  ('Giuliani', 'NNP'),
#  ('on', 'IN'),
#  ('Ukraine', 'NNP'),
#  ('matters', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('express', 'JJ'),
#  ('direction', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('President', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('United', 'NNP'),
#  ('States', 'NNPS'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('did', 'VBD'),
#  ('not', 'RB'),
#  ('want', 'VB'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('with', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Giuliani', 'NNP'),
#  ('.', '.'),
#  ('Simply', 'NNP'),
#  ('put', 'VBD'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('were', 'VBD'),
#  ('playing', 'VBG'),
#  ('the', 'DT'),
#  ('hand', 'NN'),
#  ('we', 'PRP'),
#  ('were', 'VBD'),
#  ('dealt', 'RB'),
#  ('.', '.'),
#  ('We', 'PRP'),
#  ('all', 'DT'),
#  ('understood', 'VBD'),
#  ('that', 'IN'),
#  ('if', 'IN'),
#  ('we', 'PRP'),
#  ('refuse', 'VBP'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('with', 'IN'),
#  ('Mr.', 'NNP'),
#  ('Giuliani', 'NNP'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('would', 'MD'),
#  ('lose', 'VB'),
#  ('a', 'DT'),
#  ...]

# %%
#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

import nltk, re, pprint
from nltk import word_tokenize

text = f2

#Tag text using 12 universal POS tags
tok = tokenize(text)
new2 = nltk.pos_tag(tok, tagset='universal')
#print(new2)

#Extract POS and add to list
final = []
for word, pos in new2:
    #print(word, pos)
    final.append(pos)
#print(final)

#Join list into single string
final2 = ' '.join(final)
#print(final2)

#Count POS
from collections import Counter
count = Counter([pos for word,pos in new2])
print(count)

#Calculate POS as percentage of total words

#f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

textWords = []
    
for word in tok:
    if word.isalpha():
        textWords.append(word)

tot_words = len(textWords)
print(tot_words)

NOUN = count['NOUN']/tot_words
VERB = count['VERB']/tot_words
ADP = count['ADP']/tot_words
DET = count['DET']/tot_words
PRON = count['PRON']/tot_words
ADJ = count['ADJ']/tot_words
ADV = count['ADV']/tot_words
CONJ = count['CONJ']/tot_words
PRT = count['PRT']/tot_words
NUM = count['NUM']/tot_words
X = count['X']/tot_words
print("Nouns: "+"{:.0%}".format(NOUN));
print("Verbs: "+"{:.0%}".format(VERB));
print("Adpositions: "+"{:.0%}".format(ADP));
print("Determiners: "+"{:.0%}".format(DET));
print("Pronouns: "+"{:.0%}".format(PRON));
print("Adverbs: "+"{:.0%}".format(ADV));
print("Adjectives: "+"{:.0%}".format(ADJ));
print("Conjunctions: "+"{:.0%}".format(CONJ));
print("Particles: "+"{:.0%}".format(PRT));
print("Numbers: "+"{:.0%}".format(NUM));
print("Other: "+"{:.0%}".format(X));
# Out:
# Counter({'NOUN': 815, 'VERB': 532, 'ADP': 356, 'DET': 317, '.': 287, 'PRON': 261, 'ADJ': 236, 'ADV': 163, 'CONJ': 128, 'PRT': 109, 'NUM': 34})
# 2883
# Nouns: 28%
# Verbs: 18%
# Adpositions: 12%
# Determiners: 11%
# Pronouns: 9%
# Adverbs: 6%
# Adjectives: 8%
# Conjunctions: 4%
# Particles: 4%
# Numbers: 1%
# Other: 0%

# %%
def pos_profile(text):

    import nltk, re, pprint
    from nltk import word_tokenize

    #Tag text using 12 universal POS tags
    tok = tokenize(text)
    new2 = nltk.pos_tag(tok, tagset='universal')
    #print(new2)

    #Extract POS and add to list
    final = []
    for word, pos in new2:
        #print(word, pos)
        final.append(pos)
    #print(final)

    #Join list into single string
    final2 = ' '.join(final)
    #print(final2)

    #Count POS
    from collections import Counter
    count = Counter([pos for word,pos in new2])
    print(count)

    #Calculate POS as percentage of total words

    #f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

    textWords = []

    for word in tok:
        if word.isalpha():
            textWords.append(word)

    tot_words = len(textWords)
    print(tot_words)

    NOUN = count['NOUN']/tot_words
    VERB = count['VERB']/tot_words
    ADP = count['ADP']/tot_words
    DET = count['DET']/tot_words
    PRON = count['PRON']/tot_words
    ADJ = count['ADJ']/tot_words
    ADV = count['ADV']/tot_words
    CONJ = count['CONJ']/tot_words
    PRT = count['PRT']/tot_words
    NUM = count['NUM']/tot_words
    X = count['X']/tot_words
    print("Nouns: "+"{:.0%}".format(NOUN));
    print("Verbs: "+"{:.0%}".format(VERB));
    print("Adpositions: "+"{:.0%}".format(ADP));
    print("Determiners: "+"{:.0%}".format(DET));
    print("Pronouns: "+"{:.0%}".format(PRON));
    print("Adverbs: "+"{:.0%}".format(ADV));
    print("Adjectives: "+"{:.0%}".format(ADJ));
    print("Conjunctions: "+"{:.0%}".format(CONJ));
    print("Particles: "+"{:.0%}".format(PRT));
    print("Numbers: "+"{:.0%}".format(NUM));
    print("Other: "+"{:.0%}".format(X));

# %%
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')
pos_profile(f1)
# Out:
# Counter({'NOUN': 1771, 'VERB': 900, 'ADP': 628, '.': 603, 'DET': 562, 'PRON': 424, 'ADJ': 339, 'ADV': 231, 'CONJ': 193, 'PRT': 187, 'NUM': 75, 'X': 6})
# 5053
# Nouns: 35%
# Verbs: 18%
# Adpositions: 12%
# Determiners: 11%
# Pronouns: 8%
# Adverbs: 5%
# Adjectives: 7%
# Conjunctions: 4%
# Particles: 4%
# Numbers: 1%
# Other: 0%

# %%
#Load text from a text file
f1 = open('/Users/chelseamiya/Desktop/Sondland.txt')
f2 = open('/Users/chelseamiya/Desktop/Yovanovitch.txt')

pos_profile(f2)
# Out:
# Counter({'NOUN': 815, 'VERB': 532, 'ADP': 356, 'DET': 317, '.': 287, 'PRON': 261, 'ADJ': 236, 'ADV': 163, 'CONJ': 128, 'PRT': 109, 'NUM': 34})
# 2883
# Nouns: 28%
# Verbs: 18%
# Adpositions: 12%
# Determiners: 11%
# Pronouns: 9%
# Adverbs: 6%
# Adjectives: 8%
# Conjunctions: 4%
# Particles: 4%
# Numbers: 1%
# Other: 0%
